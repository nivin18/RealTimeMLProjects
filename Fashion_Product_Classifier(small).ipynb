# %% [markdown]
# <a href="https://colab.research.google.com/github/nivin18/RealTimeMLProjects/blob/master/Fashion_Product_Classifier(small).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Downloading the Data

# %%
! pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/paramaggarwal/fashion-product-images-small")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: nivinabrahamthomas
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 565M/565M [00:26<00:00, 22.3MB/s]

# %%
cd fashion-product-images-small/
# Out:
# /content/fashion-product-images-small

# %% [markdown]
# Image name with Extentsion

# %%
import pandas as pd

# %%
df = pd.read_csv("styles.csv", error_bad_lines=False)
# Out:
# <ipython-input-6-1906ebab1cd4>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("styles.csv", error_bad_lines=False)
# Skipping line 6044: expected 10 fields, saw 11
# Skipping line 6569: expected 10 fields, saw 11
# Skipping line 7399: expected 10 fields, saw 11
# Skipping line 7939: expected 10 fields, saw 11
# Skipping line 9026: expected 10 fields, saw 11
# Skipping line 10264: expected 10 fields, saw 11
# Skipping line 10427: expected 10 fields, saw 11
# Skipping line 10905: expected 10 fields, saw 11
# Skipping line 11373: expected 10 fields, saw 11
# Skipping line 11945: expected 10 fields, saw 11
# Skipping line 14112: expected 10 fields, saw 11
# Skipping line 14532: expected 10 fields, saw 11
# Skipping line 15076: expected 10 fields, saw 12
# Skipping line 29906: expected 10 fields, saw 11
# Skipping line 31625: expected 10 fields, saw 11
# ...

# %%
df.head(10)
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# ...

# %%
df['image'] = df.apply(lambda row: str(row['id']) + ".jpg", axis =1)

# %%
df.head(10)
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 5   1855    Men        Apparel     Topwear      Tshirts       Grey  Summer
# 6  30805    Men        Apparel     Topwear       Shirts      Green  Summer
# 7  26960  Women        Apparel     Topwear       Shirts     Purple  Summer
# 8  29114    Men    Accessories       Socks        Socks  Navy Blue  Summer
# 9  30039    Men    Accessories     Watches      Watches      Black  Winter
#
#      year   usage                             productDisplayName      image
# ...

# %%
df = df.sample(frac=1)

# %%
df.head(10)
# Out:
#           id  gender masterCategory subCategory   articleType baseColour  \
# 27831  43221  Unisex       Footwear       Shoes  Casual Shoes     Maroon
# 17764  41449     Men       Footwear       Shoes  Casual Shoes      White
# 33897  49306     Men    Accessories       Socks         Socks      Black
# 7049   52959   Women        Apparel       Saree        Sarees      Green
# 15399  28108     Men        Apparel   Innerwear         Trunk       Blue
# 27712  31125   Girls        Apparel     Topwear          Tops      Peach
# 28447  42938     Men    Accessories        Bags      Handbags      Black
# 9017   32813   Women       Footwear       Shoes         Heels     Purple
# 4108   59639   Women        Apparel       Saree        Sarees      Green
# 39212   4990   Women        Apparel  Bottomwear        Shorts      White
#
#        season    year   usage  \
# 27831  Summer  2012.0  Casual
# 17764    Fall  2012.0  Casual
# 33897  Summer  2016.0  Casual
# 7049     Fall  2012.0  Ethnic
# ...

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#       id  gender masterCategory subCategory      articleType    baseColour  \
# 0  50937     Men        Apparel   Innerwear  Innerwear Vests          Grey
# 1   5394  Unisex       Footwear       Shoes     Sports Shoes         White
# 2   2385     Men       Footwear       Shoes     Casual Shoes         Brown
# 3  19473     Men        Apparel     Topwear      Sweatshirts        Purple
# 4   7571     Men        Apparel     Topwear          Tshirts         White
# 5  50701   Women        Apparel     Topwear             Tops          Pink
# 6  47412   Women    Accessories        Bags         Handbags        Orange
# 7  30247     Men       Footwear  Flip Flops       Flip Flops  Coffee Brown
# 8   5862     Men        Apparel     Topwear          Tshirts         Black
# 9  55875   Women  Personal Care       Nails      Nail Polish         Brown
#
#    season    year   usage                     productDisplayName      image
# ...

# %% [markdown]
# Preparing the Image Data Generator for Training the Model

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
batch_size = 256

image_generator = ImageDataGenerator(
    validation_split = 0.2
)

training_generator = image_generator.flow_from_dataframe(
    dataframe = df,
    directory = "images",
    x_col = "image",
    y_col = "masterCategory",
    target_size = (60,80),
    batch_size = batch_size,
    subject = "training"
)

validation_generator = image_generator.flow_from_dataframe(
    dataframe = df,
    directory = "images",
    x_col = "image",
    y_col = "masterCategory",
    target_size = (60,80),
    batch_size = batch_size,
    subject = "validation"
)
classes = len(training_generator.class_indices)
# Out:
# Found 44419 validated image filenames belonging to 7 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 5 invalid image filename(s) in x_col="image". These filename(s) will be ignored.
#   warnings.warn(
# Found 44419 validated image filenames belonging to 7 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 5 invalid image filename(s) in x_col="image". These filename(s) will be ignored.
#   warnings.warn(

# %%
classes
# Out:
# 7

# %% [markdown]
# Initializing the Model using Neural Network

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %% [markdown]
# Initializing the Model

# %%
classifier = Sequential()

# Here 32 is the number of filter the layer will use and (3,3) is the size
classifier.add(Conv2D(32,(3,3),input_shape = (60,80,3),activation = 'relu'))

# Helps in extracting important features from the images
classifier.add(MaxPooling2D(pool_size=(3, 3)))

classifier.add(Conv2D(32,(3,3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size=(3, 3)))

classifier.add(Flatten())

classifier.add(Dense(units=32, activation = 'relu'))
classifier.add(Dense(units=64, activation = 'relu'))
classifier.add(Dense(units=128, activation = 'relu'))
classifier.add(Dense(units=256, activation = 'relu'))
classifier.add(Dense(units=512, activation = 'relu'))

classifier.add(Dense(units=7, activation = 'softmax'))

classifier.compile(optimizer ='adam',
                   loss="categorical_crossentropy",
                   metrics=['accuracy'])

# %% [markdown]
# Fitting the Data in the Neural Network

# %%
from math import ceil

classifier.fit_generator(
    generator = training_generator,
    steps_per_epoch=ceil(0.8 * (df.shape[0] / batch_size)),

    validation_data = validation_generator,
    validation_freq=ceil(0.2 * (df.shape[0] / batch_size)),

    epochs = 5,
    verbose = 1
)

loss, acc = classifier.evaluate_generator(validation_generator, steps = ceil(0.2 * (df.size/ batch_size)))
print("\n%s: %.2f%%" % (classifier.metrics_names[1], acc * 100))
# Out:
# Epoch 1/5
# <ipython-input-23-3b65007ed64c>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   classifier.fit_generator(
# 139/139 [==============================] - 18s 128ms/step - loss: 0.0809 - accuracy: 0.9755
# Epoch 2/5
# 139/139 [==============================] - 19s 135ms/step - loss: 0.0806 - accuracy: 0.9758
# Epoch 3/5
# 139/139 [==============================] - 18s 127ms/step - loss: 0.0728 - accuracy: 0.9783
# Epoch 4/5
# 139/139 [==============================] - 21s 148ms/step - loss: 0.0689 - accuracy: 0.9794
# Epoch 5/5
# 139/139 [==============================] - 19s 133ms/step - loss: 0.0700 - accuracy: 0.9786
# <ipython-input-23-3b65007ed64c>:14: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
# ...

# %% [markdown]
# Saving the Model for further use

# %%
classifier.save("model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# Testing on our Data

# %%
import numpy as np
from keras.preprocessing import image
filename = "15970.jpg"

from keras.models import load_model
new_model = load_model('model.h5')
new_model.summary()

test_image = image.load_img("images/"+filename, target_size=(60,80))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)

result = new_model.predict(test_image)
print(result)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 58, 78, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 19, 26, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 17, 24, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 8, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 32)                40992
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dense_3 (Dense)             (None, 256)               33024
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  dense_5 (Dense)             (None, 7)                 3591
#
# ...
# Total params: 229767 (897.53 KB)
# Trainable params: 229767 (897.53 KB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
val = np.argmax(result)
print(val)
# Out:
# 1

# %%
my_dict = training_generator.class_indices
key_list = list(my_dict.keys())
val_list = list(my_dict.values())
print(key_list[val])
# Out:
# Apparel

# %% [markdown]
# Saving the Class IDs

# %%
import pickle
# save the model to disk
filename1 = "key_list"
filename = 'val_list'
pickle.dump(key_list, open(filename1, 'wb'))
pickle.dump(key_list, open(filename, 'wb'))
